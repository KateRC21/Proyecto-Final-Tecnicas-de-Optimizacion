# %% [markdown]
# # 02 - Prueba del Modelo de Optimización
#
# **Propósito:** Probar el modelo de optimización con un caso pequeño.
#
# **Contenido:**
# - Crear un grafo pequeño de prueba
# - Generar emergencias de prueba
# - Construir y resolver el modelo
# - Analizar resultados
# - Visualizar solución

# %%
# TODO: Imports
# import sys
# sys.path.append('..')

# from src.models.optimization_model import AmbulanceOptimizationModel
# from src.simulation.emergency_generator import generar_emergencias
# from config import PARAMETROS, COSTOS, HOSPITALES
