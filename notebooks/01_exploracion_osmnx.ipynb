# %% [markdown]
# # 01 - Exploración de OSMnx
#
# **Propósito:** Explorar las capacidades de OSMnx para descargar y visualizar mapas de Medellín.
#
# **Contenido:**
# - Instalación y configuración de OSMnx
# - Descarga del mapa de Medellín
# - Exploración de la estructura del grafo
# - Visualización básica
# - Análisis de atributos de nodos y aristas
# - Guardado y carga de grafos

# %%
# TODO: Imports necesarios
# import osmnx as ox
# import networkx as nx
# import matplotlib.pyplot as plt
# import pandas as pd

# Configuración de OSMnx
# ox.settings.log_console = True
# ox.settings.use_cache = True
